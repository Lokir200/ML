# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
iris

# %%
#min max
x=[1,3,5,6,7,8,21,31,31,37,12,509]
y=[]
min=1
max=509
for i in range(len(X)):
    y.append((x[i]-min)/(max-min))
print(y)
# Out:
# [0.0, 0.003937007874015748, 0.007874015748031496, 0.00984251968503937, 0.011811023622047244, 0.013779527559055118, 0.03937007874015748, 0.05905511811023622, 0.05905511811023622, 0.07086614173228346, 0.021653543307086614, 1.0]

# %%
#decimal scaling
x=[1,3,5,6,7,8,21,31,31,37,12,509]
y=[]
j=3
for i in range(len(X)):
    y.append(x[i]/10**j)
print(y)
# Out:
# [0.001, 0.003, 0.005, 0.006, 0.007, 0.008, 0.021, 0.031, 0.031, 0.037, 0.012, 0.509]

# %%
x=[1,3,5,6,7,8,21,31,31,37,12,509]
sum=0
for i in range(len(X)):
   sum=sum+a[i]
mean=sum/len(x)
print("mean",mean)
   var=(a[x]-mean)**2/len(a)
   std=np.sqrt(var)
   y.append(x-mean)
print()
# Out:
#   Cell In[9], line 7
#     var=(a[x]-mean)**2/len(a)
#     ^
# IndentationError: unexpected indent

# %%
import numpy as np
a=[1,2,3,np.nan,4,5,6,7,8,21,31,31,37,12,509]

print(a)
# Out:
# [1, 2, 3, nan, 4, 5, 6, 7, 8, 21, 31, 31, 37, 12, 509]

# %%
x=[1,3,5,6,7,8,21,31,31,37,12,509]
sum=0
for i in range(len(X)):
   sum=sum+a[i]
   mean=sum/len(x)
print(mean)
# Out:
# nan

# %%
x=[1,2,3,np.nan,4,5,6,7,8,21,31,31,37,12,509]

total = 0
for i in range(len(x)):
    total += x[i]

mean = total / len(x)
print(mean)
# Out:
# nan

# %%
import numpy as np
a=[1,2,3,np.nan,4,5,6,7,8,21,31,31,37,12,509]
count=0
sum=0
for i in range(len(a)):
    if np.isnan(a[i]) == True:
       remember_index=i
       print('None value sorted in the index',i)
       count=count+1
    else:
        sum=sum+a[i]
Mean=sum/(len(a)-count)
a[remember_index]=mean
print(a)
# Out:
# None value sorted in the index 3
# [1, 2, 3, 48.357142857142854, 4, 5, 6, 7, 8, 21, 31, 31, 37, 12, 509]
